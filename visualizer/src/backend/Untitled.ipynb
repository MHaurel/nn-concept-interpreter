# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_json("df_cat.json")
df2 = pd.read_json("df_ncat.json")

# %%
df1
# Out:
#                                                   neuron_1  neuron_2  \
# http://dbpedia.org/resource/Howardena_Pindell    -0.013268 -0.407272
# http://dbpedia.org/resource/James_Rosenquist     -0.710980 -1.178149
# http://dbpedia.org/resource/Winslow_Homer        -0.330038 -0.795130
# http://dbpedia.org/resource/Charles_Arnoldi      -3.259392 -3.258079
# http://dbpedia.org/resource/Lyndall_Bass          0.281395  0.287122
# ...                                                    ...       ...
# http://dbpedia.org/resource/Robert_Beauchamp      0.137995  0.204014
# http://dbpedia.org/resource/Scott_Jacobs          0.415826  0.724063
# http://dbpedia.org/resource/Bonnie_Bronson       -1.313900 -1.040402
# http://dbpedia.org/resource/Edward_Williams_Clay  0.508768  0.586284
# http://dbpedia.org/resource/Garner_Tullis         0.560377  0.563015
#
#                                                   neuron_3  neuron_4  \
# ...

# %%
df2
# Out:
#                                                     neuron_1  neuron_2  \
# http://dbpedia.org/resource/Alexander_Semionov      0.547359 -0.328434
# http://dbpedia.org/resource/Étienne_Moreau-Nélaton  0.934530  0.158398
# http://dbpedia.org/resource/Albert_Bierstadt       -0.456486 -1.654435
# http://dbpedia.org/resource/Boris_Maluev            0.430946 -1.050859
# http://dbpedia.org/resource/Vyacheslav_Ovchinni...  0.502531 -1.310737
# ...                                                      ...       ...
# http://dbpedia.org/resource/Duncan_Sommerville     -0.652709  0.318967
# http://dbpedia.org/resource/Alexis_Simon_Belle      0.422954  0.263803
# http://dbpedia.org/resource/Jazeh_Tabatabai         0.040576  0.129953
# http://dbpedia.org/resource/Luis_Germán_Cajiga      0.210663  0.808387
# http://dbpedia.org/resource/Bernard_Lorjou          0.851085  0.592630
#
#                                                     neuron_3  neuron_4  \
# ...

# %%
abs((df1.mean() - df2.mean()).max())
# Out:
# 0.39862747120264963
